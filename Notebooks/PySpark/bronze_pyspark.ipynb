# %%
# 1. Read the CSV customer_info
df_customer_data = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("/Volumes/sales_sports_pyspark/00_bronze_pyspark/sales_pyspark/cust_info.csv")
df_customer_data.write.mode("overwrite").saveAsTable("sales_sports_pyspark.00_bronze_pyspark.crm_cust_info")

# 2. Read the CSV product_info
df_product_info = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("/Volumes/sales_sports_pyspark/00_bronze_pyspark/sales_pyspark/prd_info.csv")
df_product_info.write.mode("overwrite").saveAsTable("sales_sports_pyspark.00_bronze_pyspark.crm_product_info")

# 2. Read the CSV sales_details
df_sales_details = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("/Volumes/sales_sports_pyspark/00_bronze_pyspark/sales_pyspark/sales_details.csv")
df_sales_details.write.mode("overwrite").saveAsTable("sales_sports_pyspark.00_bronze_pyspark.crm_sales_details")

# 3. Read the CSV cust_az12
df_cust_az12 = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("/Volumes/sales_sports_pyspark/00_bronze_pyspark/sales_pyspark/CUST_AZ12.csv")
df_cust_az12.write.mode("overwrite").saveAsTable("sales_sports_pyspark.00_bronze_pyspark.erp_cust_az12")

# 4. Read the CSV loc_a101
df_loc_a101 = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("/Volumes/sales_sports_pyspark/00_bronze_pyspark/sales_pyspark/LOC_A101.csv")
df_loc_a101.write.mode("overwrite").saveAsTable("sales_sports_pyspark.00_bronze_pyspark.erp_loc_a101")

# 5. Read the CSV px_cat_g1v2
df_px_cat_g1v2 = spark.read.format("csv") \
  .option("header", "true") \
  .option("inferSchema", "true") \
  .load("/Volumes/sales_sports_pyspark/00_bronze_pyspark/sales_pyspark/PX_CAT_G1V2.csv")
df_px_cat_g1v2.write.mode("overwrite").saveAsTable("sales_sports_pyspark.00_bronze_pyspark.erp_px_cat_g1v2")
